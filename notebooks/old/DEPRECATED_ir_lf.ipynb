# %%
# %cd ~/github/agn_lf/
import source.astro_functions as af
import source.table_functions as tf
import source.lf_xi2 as xi2
import source.vmax as vmax
import source.utils as utils
import source.selection_criteria as sc
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import astropy.table as table
import astropy.units as u

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /Users/runburg/github/agn_lf
# <style>.container { width:100% !important; }</style>

# %%
xmmlss = fits.open('./data/XMM-LSS_20190328.fits')

# %%
xmmlss[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                 3394 / width of table in bytes
# NAXIS2  =              8705837 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                  475 / number of columns
# EXTNAME = './data/tiles/xmm-lss_20190328_0.fits' / table name
# TTYPE1  = 'help_id '           / label for column 1
# TFORM1  = '27A     '           / format for column 1
# TTYPE2  = 'field   '           / label for column 2
# TFORM2  = '18A     '           / format for column 2
# TTYPE3  = 'ra      '           / label for column 3
# TFORM3  = 'D       '           / format for column 3
# TUNIT3  = 'deg     '           / units for column 3
# TTYPE4  = 'dec     '           / label for column 4
# TFORM4  = 'D       '           / format for column 4
# TUNIT4  = 'deg     '           / units for column 4
# TTYPE5  = 'hp_idx  '           / label for column 5
# TFORM5  = 'K       '           / format for column 5
# TTYPE6  = 'ebv     '           / label for column 6
# TFORM6  = 'D       '           / format for column 6
# TTYPE7  = 'redshift'           / label for column 7
# TFORM7  = 'D       '           / format for column 7
# TTYPE8  = 'zspec   '           / label for column 8
# TFORM8  = 'D       '           / format for column 8
# TTYPE9  = 'f_megacam_u'        / label for column 9
# TFORM9  = 'D       '           / format for column 9
# TUNIT9  = 'uJy     '           / units for column 9
# TTYPE10 = 'ferr_megacam_u'     / label for column 10
# TFORM10 = 'D       '           / format for column 10
# TUNIT10 = 'uJy     '           / units for column 10
# TTYPE11 = 'f_ap_megacam_u'     / label for column 11
# TFORM11 = 'D       '           / format for column 11
# TUNIT11 = 'uJy     '           / units for column 11
# TTYPE12 = 'ferr_ap_megacam_u'  / label for column 12
# TFORM12 = 'D       '           / format for column 12
# TUNIT12 = 'uJy     '           / units for column 12
# TTYPE13 = 'm_megacam_u'        / label for column 13
# TFORM13 = 'D       '           / format for column 13
# TUNIT13 = 'mag     '           / units for column 13
# TTYPE14 = 'merr_megacam_u'     / label for column 14
# TFORM14 = 'D       '           / format for column 14
# TUNIT14 = 'mag     '           / units for column 14
# TTYPE15 = 'm_ap_megacam_u'     / label for column 15
# TFORM15 = 'D       '           / format for column 15
# TUNIT15 = 'mag     '           / units for column 15
# TTYPE16 = 'merr_ap_megacam_u'  / label for column 16
# TFORM16 = 'D       '           / format for column 16
# TUNIT16 = 'mag     '           / units for column 16
# TTYPE17 = 'flag_megacam_u'     / label for column 17
# TFORM17 = 'L       '           / format for column 17
# TTYPE18 = 'f_suprime_b'        / label for column 18
# TFORM18 = 'D       '           / format for column 18
# TUNIT18 = 'uJy     '           / units for column 18
# TTYPE19 = 'ferr_suprime_b'     / label for column 19
# TFORM19 = 'D       '           / format for column 19
# TUNIT19 = 'uJy     '           / units for column 19
# TTYPE20 = 'f_ap_suprime_b'     / label for column 20
# TFORM20 = 'D       '           / format for column 20
# TUNIT20 = 'uJy     '           / units for column 20
# TTYPE21 = 'ferr_ap_suprime_b'  / label for column 21
# TFORM21 = 'D       '           / format for column 21
# TUNIT21 = 'uJy     '           / units for column 21
# TTYPE22 = 'm_suprime_b'        / label for column 22
# TFORM22 = 'D       '           / format for column 22
# TUNIT22 = 'mag     '           / units for column 22
# TTYPE23 = 'merr_suprime_b'     / label for column 23
# TFORM23 = 'D       '           / format for column 23
# TUNIT23 = 'mag     '           / units for column 23
# TTYPE24 = 'm_ap_suprime_b'     / label for column 24
# TFORM24 = 'D       '           / format for column 24
# TUNIT24 = 'mag     '           / units for column 24
# TTYPE25 = 'merr_ap_suprime_b'  / label for column 25
# TFORM25 = 'D       '           / format for column 25
# TUNIT25 = 'mag     '           / units for column 25
# TTYPE26 = 'flag_suprime_b'     / label for column 26
# TFORM26 = 'L       '           / format for column 26
# TTYPE27 = 'f_suprime_g'        / label for column 27
# TFORM27 = 'D       '           / format for column 27
# TUNIT27 = 'uJy     '           / units for column 27
# TTYPE28 = 'ferr_suprime_g'     / label for column 28
# TFORM28 = 'D       '           / format for column 28
# TUNIT28 = 'uJy     '           / units for column 28
# TTYPE29 = 'f_ap_suprime_g'     / label for column 29
# TFORM29 = 'D       '           / format for column 29
# TUNIT29 = 'uJy     '           / units for column 29
# TTYPE30 = 'ferr_ap_suprime_g'  / label for column 30
# TFORM30 = 'D       '           / format for column 30
# TUNIT30 = 'uJy     '           / units for column 30
# TTYPE31 = 'm_suprime_g'        / label for column 31
# TFORM31 = 'D       '           / format for column 31
# TUNIT31 = 'mag     '           / units for column 31
# TTYPE32 = 'merr_suprime_g'     / label for column 32
# TFORM32 = 'D       '           / format for column 32
# TUNIT32 = 'mag     '           / units for column 32
# TTYPE33 = 'm_ap_suprime_g'     / label for column 33
# TFORM33 = 'D       '           / format for column 33
# TUNIT33 = 'mag     '           / units for column 33
# TTYPE34 = 'merr_ap_suprime_g'  / label for column 34
# TFORM34 = 'D       '           / format for column 34
# TUNIT34 = 'mag     '           / units for column 34
# TTYPE35 = 'flag_suprime_g'     / label for column 35
# TFORM35 = 'L       '           / format for column 35
# TTYPE36 = 'f_decam_g'          / label for column 36
# TFORM36 = 'D       '           / format for column 36
# TUNIT36 = 'uJy     '           / units for column 36
# TTYPE37 = 'ferr_decam_g'       / label for column 37
# TFORM37 = 'D       '           / format for column 37
# TUNIT37 = 'uJy     '           / units for column 37
# TTYPE38 = 'f_ap_decam_g'       / label for column 38
# TFORM38 = 'D       '           / format for column 38
# TUNIT38 = 'uJy     '           / units for column 38
# TTYPE39 = 'ferr_ap_decam_g'    / label for column 39
# TFORM39 = 'D       '           / format for column 39
# TUNIT39 = 'uJy     '           / units for column 39
# TTYPE40 = 'm_decam_g'          / label for column 40
# TFORM40 = 'D       '           / format for column 40
# TUNIT40 = 'mag     '           / units for column 40
# TTYPE41 = 'merr_decam_g'       / label for column 41
# TFORM41 = 'D       '           / format for column 41
# TUNIT41 = 'mag     '           / units for column 41
# TTYPE42 = 'm_ap_decam_g'       / label for column 42
# TFORM42 = 'D       '           / format for column 42
# TUNIT42 = 'mag     '           / units for column 42
# TTYPE43 = 'merr_ap_decam_g'    / label for column 43
# TFORM43 = 'D       '           / format for column 43
# TUNIT43 = 'mag     '           / units for column 43
# TTYPE44 = 'flag_decam_g'       / label for column 44
# TFORM44 = 'L       '           / format for column 44
# TTYPE45 = 'f_megacam_g'        / label for column 45
# TFORM45 = 'D       '           / format for column 45
# TUNIT45 = 'uJy     '           / units for column 45
# TTYPE46 = 'ferr_megacam_g'     / label for column 46
# TFORM46 = 'D       '           / format for column 46
# TUNIT46 = 'uJy     '           / units for column 46
# TTYPE47 = 'f_ap_megacam_g'     / label for column 47
# TFORM47 = 'D       '           / format for column 47
# TUNIT47 = 'uJy     '           / units for column 47
# TTYPE48 = 'ferr_ap_megacam_g'  / label for column 48
# TFORM48 = 'D       '           / format for column 48
# TUNIT48 = 'uJy     '           / units for column 48
# TTYPE49 = 'm_megacam_g'        / label for column 49
# TFORM49 = 'D       '           / format for column 49
# TUNIT49 = 'mag     '           / units for column 49
# TTYPE50 = 'merr_megacam_g'     / label for column 50
# TFORM50 = 'D       '           / format for column 50
# TUNIT50 = 'mag     '           / units for column 50
# TTYPE51 = 'm_ap_megacam_g'     / label for column 51
# TFORM51 = 'D       '           / format for column 51
# TUNIT51 = 'mag     '           / units for column 51
# TTYPE52 = 'merr_ap_megacam_g'  / label for column 52
# TFORM52 = 'D       '           / format for column 52
# TUNIT52 = 'mag     '           / units for column 52
# TTYPE53 = 'flag_megacam_g'     / label for column 53
# TFORM53 = 'L       '           / format for column 53
# TTYPE54 = 'f_gpc1_g'           / label for column 54
# TFORM54 = 'D       '           / format for column 54
# TUNIT54 = 'uJy     '           / units for column 54
# TTYPE55 = 'ferr_gpc1_g'        / label for column 55
# TFORM55 = 'D       '           / format for column 55
# TUNIT55 = 'uJy     '           / units for column 55
# TTYPE56 = 'f_ap_gpc1_g'        / label for column 56
# TFORM56 = 'D       '           / format for column 56
# TUNIT56 = 'uJy     '           / units for column 56
# TTYPE57 = 'ferr_ap_gpc1_g'     / label for column 57
# TFORM57 = 'D       '           / format for column 57
# TUNIT57 = 'uJy     '           / units for column 57
# TTYPE58 = 'm_gpc1_g'           / label for column 58
# TFORM58 = 'D       '           / format for column 58
# TUNIT58 = 'mag     '           / units for column 58
# TTYPE59 = 'merr_gpc1_g'        / label for column 59
# TFORM59 = 'D       '           / format for column 59
# TUNIT59 = 'mag     '           / units for column 59
# TTYPE60 = 'm_ap_gpc1_g'        / label for column 60
# TFORM60 = 'D       '           / format for column 60
# TUNIT60 = 'mag     '           / units for column 60
# TTYPE61 = 'merr_ap_gpc1_g'     / label for column 61
# TFORM61 = 'D       '           / format for column 61
# TUNIT61 = 'mag     '           / units for column 61
# TTYPE62 = 'flag_gpc1_g'        / label for column 62
# TFORM62 = 'L       '           / format for column 62
# TTYPE63 = 'f_suprime_v'        / label for column 63
# TFORM63 = 'D       '           / format for column 63
# TUNIT63 = 'uJy     '           / units for column 63
# TTYPE64 = 'ferr_suprime_v'     / label for column 64
# TFORM64 = 'D       '           / format for column 64
# TUNIT64 = 'uJy     '           / units for column 64
# TTYPE65 = 'f_ap_suprime_v'     / label for column 65
# TFORM65 = 'D       '           / format for column 65
# TUNIT65 = 'uJy     '           / units for column 65
# TTYPE66 = 'ferr_ap_suprime_v'  / label for column 66
# TFORM66 = 'D       '           / format for column 66
# TUNIT66 = 'uJy     '           / units for column 66
# TTYPE67 = 'm_suprime_v'        / label for column 67
# TFORM67 = 'D       '           / format for column 67
# TUNIT67 = 'mag     '           / units for column 67
# TTYPE68 = 'merr_suprime_v'     / label for column 68
# TFORM68 = 'D       '           / format for column 68
# TUNIT68 = 'mag     '           / units for column 68
# TTYPE69 = 'm_ap_suprime_v'     / label for column 69
# TFORM69 = 'D       '           / format for column 69
# TUNIT69 = 'mag     '           / units for column 69
# TTYPE70 = 'merr_ap_suprime_v'  / label for column 70
# TFORM70 = 'D       '           / format for column 70
# TUNIT70 = 'mag     '           / units for column 70
# TTYPE71 = 'flag_suprime_v'     / label for column 71
# TFORM71 = 'L       '           / format for column 71
# TTYPE72 = 'f_acs_f606w'        / label for column 72
# TFORM72 = 'D       '           / format for column 72
# TUNIT72 = 'uJy     '           / units for column 72
# TTYPE73 = 'ferr_acs_f606w'     / label for column 73
# TFORM73 = 'D       '           / format for column 73
# TUNIT73 = 'uJy     '           / units for column 73
# TTYPE74 = 'f_ap_acs_f606w'     / label for column 74
# TFORM74 = 'D       '           / format for column 74
# TUNIT74 = 'uJy     '           / units for column 74
# TTYPE75 = 'ferr_ap_acs_f606w'  / label for column 75
# TFORM75 = 'D       '           / format for column 75
# TUNIT75 = 'uJy     '           / units for column 75
# TTYPE76 = 'm_acs_f606w'        / label for column 76
# TFORM76 = 'D       '           / format for column 76
# TUNIT76 = 'mag     '           / units for column 76
# TTYPE77 = 'merr_acs_f606w'     / label for column 77
# TFORM77 = 'D       '           / format for column 77
# TUNIT77 = 'mag     '           / units for column 77
# TTYPE78 = 'm_ap_acs_f606w'     / label for column 78
# TFORM78 = 'D       '           / format for column 78
# TUNIT78 = 'mag     '           / units for column 78
# TTYPE79 = 'merr_ap_acs_f606w'  / label for column 79
# TFORM79 = 'D       '           / format for column 79
# TUNIT79 = 'mag     '           / units for column 79
# TTYPE80 = 'flag_acs_f606w'     / label for column 80
# TFORM80 = 'L       '           / format for column 80
# TTYPE81 = 'f_suprime_r'        / label for column 81
# TFORM81 = 'D       '           / format for column 81
# TUNIT81 = 'uJy     '           / units for column 81
# TTYPE82 = 'ferr_suprime_r'     / label for column 82
# TFORM82 = 'D       '           / format for column 82
# TUNIT82 = 'uJy     '           / units for column 82
# TTYPE83 = 'f_ap_suprime_r'     / label for column 83
# TFORM83 = 'D       '           / format for column 83
# TUNIT83 = 'uJy     '           / units for column 83
# TTYPE84 = 'ferr_ap_suprime_r'  / label for column 84
# TFORM84 = 'D       '           / format for column 84
# TUNIT84 = 'uJy     '           / units for column 84
# TTYPE85 = 'm_suprime_r'        / label for column 85
# TFORM85 = 'D       '           / format for column 85
# TUNIT85 = 'mag     '           / units for column 85
# TTYPE86 = 'merr_suprime_r'     / label for column 86
# TFORM86 = 'D       '           / format for column 86
# TUNIT86 = 'mag     '           / units for column 86
# TTYPE87 = 'm_ap_suprime_r'     / label for column 87
# TFORM87 = 'D       '           / format for column 87
# TUNIT87 = 'mag     '           / units for column 87
# TTYPE88 = 'merr_ap_suprime_r'  / label for column 88
# TFORM88 = 'D       '           / format for column 88
# TUNIT88 = 'mag     '           / units for column 88
# TTYPE89 = 'flag_suprime_r'     / label for column 89
# TFORM89 = 'L       '           / format for column 89
# TTYPE90 = 'f_gpc1_r'           / label for column 90
# TFORM90 = 'D       '           / format for column 90
# TUNIT90 = 'uJy     '           / units for column 90
# TTYPE91 = 'ferr_gpc1_r'        / label for column 91
# TFORM91 = 'D       '           / format for column 91
# TUNIT91 = 'uJy     '           / units for column 91
# TTYPE92 = 'f_ap_gpc1_r'        / label for column 92
# TFORM92 = 'D       '           / format for column 92
# TUNIT92 = 'uJy     '           / units for column 92
# TTYPE93 = 'ferr_ap_gpc1_r'     / label for column 93
# TFORM93 = 'D       '           / format for column 93
# TUNIT93 = 'uJy     '           / units for column 93
# TTYPE94 = 'm_gpc1_r'           / label for column 94
# TFORM94 = 'D       '           / format for column 94
# TUNIT94 = 'mag     '           / units for column 94
# TTYPE95 = 'merr_gpc1_r'        / label for column 95
# TFORM95 = 'D       '           / format for column 95
# TUNIT95 = 'mag     '           / units for column 95
# TTYPE96 = 'm_ap_gpc1_r'        / label for column 96
# TFORM96 = 'D       '           / format for column 96
# TUNIT96 = 'mag     '           / units for column 96
# TTYPE97 = 'merr_ap_gpc1_r'     / label for column 97
# TFORM97 = 'D       '           / format for column 97
# TUNIT97 = 'mag     '           / units for column 97
# TTYPE98 = 'flag_gpc1_r'        / label for column 98
# TFORM98 = 'L       '           / format for column 98
# TTYPE99 = 'f_megacam_r'        / label for column 99
# TFORM99 = 'D       '           / format for column 99
# TUNIT99 = 'uJy     '           / units for column 99
# TTYPE100= 'ferr_megacam_r'     / label for column 100
# TFORM100= 'D       '           / format for column 100
# TUNIT100= 'uJy     '           / units for column 100
# TTYPE101= 'f_ap_megacam_r'     / label for column 101
# TFORM101= 'D       '           / format for column 101
# TUNIT101= 'uJy     '           / units for column 101
# TTYPE102= 'ferr_ap_megacam_r'  / label for column 102
# TFORM102= 'D       '           / format for column 102
# TUNIT102= 'uJy     '           / units for column 102
# TTYPE103= 'm_megacam_r'        / label for column 103
# TFORM103= 'D       '           / format for column 103
# TUNIT103= 'mag     '           / units for column 103
# TTYPE104= 'merr_megacam_r'     / label for column 104
# TFORM104= 'D       '           / format for column 104
# TUNIT104= 'mag     '           / units for column 104
# TTYPE105= 'm_ap_megacam_r'     / label for column 105
# TFORM105= 'D       '           / format for column 105
# TUNIT105= 'mag     '           / units for column 105
# TTYPE106= 'merr_ap_megacam_r'  / label for column 106
# TFORM106= 'D       '           / format for column 106
# TUNIT106= 'mag     '           / units for column 106
# TTYPE107= 'flag_megacam_r'     / label for column 107
# TFORM107= 'L       '           / format for column 107
# TTYPE108= 'f_decam_r'          / label for column 108
# TFORM108= 'D       '           / format for column 108
# TUNIT108= 'uJy     '           / units for column 108
# TTYPE109= 'ferr_decam_r'       / label for column 109
# TFORM109= 'D       '           / format for column 109
# TUNIT109= 'uJy     '           / units for column 109
# TTYPE110= 'f_ap_decam_r'       / label for column 110
# TFORM110= 'D       '           / format for column 110
# TUNIT110= 'uJy     '           / units for column 110
# TTYPE111= 'ferr_ap_decam_r'    / label for column 111
# TFORM111= 'D       '           / format for column 111
# TUNIT111= 'uJy     '           / units for column 111
# TTYPE112= 'm_decam_r'          / label for column 112
# TFORM112= 'D       '           / format for column 112
# TUNIT112= 'mag     '           / units for column 112
# TTYPE113= 'merr_decam_r'       / label for column 113
# TFORM113= 'D       '           / format for column 113
# TUNIT113= 'mag     '           / units for column 113
# TTYPE114= 'm_ap_decam_r'       / label for column 114
# TFORM114= 'D       '           / format for column 114
# TUNIT114= 'mag     '           / units for column 114
# TTYPE115= 'merr_ap_decam_r'    / label for column 115
# TFORM115= 'D       '           / format for column 115
# TUNIT115= 'mag     '           / units for column 115
# TTYPE116= 'flag_decam_r'       / label for column 116
# TFORM116= 'L       '           / format for column 116
# TTYPE117= 'f_suprime_rc'       / label for column 117
# TFORM117= 'D       '           / format for column 117
# TUNIT117= 'uJy     '           / units for column 117
# TTYPE118= 'ferr_suprime_rc'    / label for column 118
# TFORM118= 'D       '           / format for column 118
# TUNIT118= 'uJy     '           / units for column 118
# TTYPE119= 'f_ap_suprime_rc'    / label for column 119
# TFORM119= 'D       '           / format for column 119
# TUNIT119= 'uJy     '           / units for column 119
# TTYPE120= 'ferr_ap_suprime_rc' / label for column 120
# TFORM120= 'D       '           / format for column 120
# TUNIT120= 'uJy     '           / units for column 120
# TTYPE121= 'm_suprime_rc'       / label for column 121
# TFORM121= 'D       '           / format for column 121
# TUNIT121= 'mag     '           / units for column 121
# TTYPE122= 'merr_suprime_rc'    / label for column 122
# TFORM122= 'D       '           / format for column 122
# TUNIT122= 'mag     '           / units for column 122
# TTYPE123= 'm_ap_suprime_rc'    / label for column 123
# TFORM123= 'D       '           / format for column 123
# TUNIT123= 'mag     '           / units for column 123
# TTYPE124= 'merr_ap_suprime_rc' / label for column 124
# TFORM124= 'D       '           / format for column 124
# TUNIT124= 'mag     '           / units for column 124
# TTYPE125= 'flag_suprime_rc'    / label for column 125
# TFORM125= 'L       '           / format for column 125
# TTYPE126= 'f_gpc1_i'           / label for column 126
# TFORM126= 'D       '           / format for column 126
# TUNIT126= 'uJy     '           / units for column 126
# TTYPE127= 'ferr_gpc1_i'        / label for column 127
# TFORM127= 'D       '           / format for column 127
# TUNIT127= 'uJy     '           / units for column 127
# TTYPE128= 'f_ap_gpc1_i'        / label for column 128
# TFORM128= 'D       '           / format for column 128
# TUNIT128= 'uJy     '           / units for column 128
# TTYPE129= 'ferr_ap_gpc1_i'     / label for column 129
# TFORM129= 'D       '           / format for column 129
# TUNIT129= 'uJy     '           / units for column 129
# TTYPE130= 'm_gpc1_i'           / label for column 130
# TFORM130= 'D       '           / format for column 130
# TUNIT130= 'mag     '           / units for column 130
# TTYPE131= 'merr_gpc1_i'        / label for column 131
# TFORM131= 'D       '           / format for column 131
# TUNIT131= 'mag     '           / units for column 131
# TTYPE132= 'm_ap_gpc1_i'        / label for column 132
# TFORM132= 'D       '           / format for column 132
# TUNIT132= 'mag     '           / units for column 132
# TTYPE133= 'merr_ap_gpc1_i'     / label for column 133
# TFORM133= 'D       '           / format for column 133
# TUNIT133= 'mag     '           / units for column 133
# TTYPE134= 'flag_gpc1_i'        / label for column 134
# TFORM134= 'L       '           / format for column 134
# TTYPE135= 'f_megacam_i'        / label for column 135
# TFORM135= 'D       '           / format for column 135
# TUNIT135= 'uJy     '           / units for column 135
# TTYPE136= 'ferr_megacam_i'     / label for column 136
# TFORM136= 'D       '           / format for column 136
# TUNIT136= 'uJy     '           / units for column 136
# TTYPE137= 'f_ap_megacam_i'     / label for column 137
# TFORM137= 'D       '           / format for column 137
# TUNIT137= 'uJy     '           / units for column 137
# TTYPE138= 'ferr_ap_megacam_i'  / label for column 138
# TFORM138= 'D       '           / format for column 138
# TUNIT138= 'uJy     '           / units for column 138
# TTYPE139= 'm_megacam_i'        / label for column 139
# TFORM139= 'D       '           / format for column 139
# TUNIT139= 'mag     '           / units for column 139
# TTYPE140= 'merr_megacam_i'     / label for column 140
# TFORM140= 'D       '           / format for column 140
# TUNIT140= 'mag     '           / units for column 140
# TTYPE141= 'm_ap_megacam_i'     / label for column 141
# TFORM141= 'D       '           / format for column 141
# TUNIT141= 'mag     '           / units for column 141
# TTYPE142= 'merr_ap_megacam_i'  / label for column 142
# TFORM142= 'D       '           / format for column 142
# TUNIT142= 'mag     '           / units for column 142
# TTYPE143= 'flag_megacam_i'     / label for column 143
# TFORM143= 'L       '           / format for column 143
# TTYPE144= 'f_suprime_ip'       / label for column 144
# TFORM144= 'D       '           / format for column 144
# TUNIT144= 'uJy     '           / units for column 144
# TTYPE145= 'ferr_suprime_ip'    / label for column 145
# TFORM145= 'D       '           / format for column 145
# TUNIT145= 'uJy     '           / units for column 145
# TTYPE146= 'f_ap_suprime_ip'    / label for column 146
# TFORM146= 'D       '           / format for column 146
# TUNIT146= 'uJy     '           / units for column 146
# TTYPE147= 'ferr_ap_suprime_ip' / label for column 147
# TFORM147= 'D       '           / format for column 147
# TUNIT147= 'uJy     '           / units for column 147
# TTYPE148= 'm_suprime_ip'       / label for column 148
# TFORM148= 'D       '           / format for column 148
# TUNIT148= 'mag     '           / units for column 148
# TTYPE149= 'merr_suprime_ip'    / label for column 149
# TFORM149= 'D       '           / format for column 149
# TUNIT149= 'mag     '           / units for column 149
# TTYPE150= 'm_ap_suprime_ip'    / label for column 150
# TFORM150= 'D       '           / format for column 150
# TUNIT150= 'mag     '           / units for column 150
# TTYPE151= 'merr_ap_suprime_ip' / label for column 151
# TFORM151= 'D       '           / format for column 151
# TUNIT151= 'mag     '           / units for column 151
# TTYPE152= 'flag_suprime_ip'    / label for column 152
# TFORM152= 'L       '           / format for column 152
# TTYPE153= 'f_megacam_y'        / label for column 153
# TFORM153= 'D       '           / format for column 153
# TUNIT153= 'uJy     '           / units for column 153
# TTYPE154= 'ferr_megacam_y'     / label for column 154
# TFORM154= 'D       '           / format for column 154
# TUNIT154= 'uJy     '           / units for column 154
# TTYPE155= 'f_ap_megacam_y'     / label for column 155
# TFORM155= 'D       '           / format for column 155
# TUNIT155= 'uJy     '           / units for column 155
# TTYPE156= 'ferr_ap_megacam_y'  / label for column 156
# TFORM156= 'D       '           / format for column 156
# TUNIT156= 'uJy     '           / units for column 156
# TTYPE157= 'm_megacam_y'        / label for column 157
# TFORM157= 'D       '           / format for column 157
# TUNIT157= 'mag     '           / units for column 157
# TTYPE158= 'merr_megacam_y'     / label for column 158
# TFORM158= 'D       '           / format for column 158
# TUNIT158= 'mag     '           / units for column 158
# TTYPE159= 'm_ap_megacam_y'     / label for column 159
# TFORM159= 'D       '           / format for column 159
# TUNIT159= 'mag     '           / units for column 159
# TTYPE160= 'merr_ap_megacam_y'  / label for column 160
# TFORM160= 'D       '           / format for column 160
# TUNIT160= 'mag     '           / units for column 160
# TTYPE161= 'flag_megacam_y'     / label for column 161
# TFORM161= 'L       '           / format for column 161
# TTYPE162= 'f_suprime_i'        / label for column 162
# TFORM162= 'D       '           / format for column 162
# TUNIT162= 'uJy     '           / units for column 162
# TTYPE163= 'ferr_suprime_i'     / label for column 163
# TFORM163= 'D       '           / format for column 163
# TUNIT163= 'uJy     '           / units for column 163
# TTYPE164= 'f_ap_suprime_i'     / label for column 164
# TFORM164= 'D       '           / format for column 164
# TUNIT164= 'uJy     '           / units for column 164
# TTYPE165= 'ferr_ap_suprime_i'  / label for column 165
# TFORM165= 'D       '           / format for column 165
# TUNIT165= 'uJy     '           / units for column 165
# TTYPE166= 'm_suprime_i'        / label for column 166
# TFORM166= 'D       '           / format for column 166
# TUNIT166= 'mag     '           / units for column 166
# TTYPE167= 'merr_suprime_i'     / label for column 167
# TFORM167= 'D       '           / format for column 167
# TUNIT167= 'mag     '           / units for column 167
# TTYPE168= 'm_ap_suprime_i'     / label for column 168
# TFORM168= 'D       '           / format for column 168
# TUNIT168= 'mag     '           / units for column 168
# TTYPE169= 'merr_ap_suprime_i'  / label for column 169
# TFORM169= 'D       '           / format for column 169
# TUNIT169= 'mag     '           / units for column 169
# TTYPE170= 'flag_suprime_i'     / label for column 170
# TFORM170= 'L       '           / format for column 170
# TTYPE171= 'f_decam_i'          / label for column 171
# TFORM171= 'D       '           / format for column 171
# TUNIT171= 'uJy     '           / units for column 171
# TTYPE172= 'ferr_decam_i'       / label for column 172
# TFORM172= 'D       '           / format for column 172
# TUNIT172= 'uJy     '           / units for column 172
# TTYPE173= 'f_ap_decam_i'       / label for column 173
# TFORM173= 'D       '           / format for column 173
# TUNIT173= 'uJy     '           / units for column 173
# TTYPE174= 'ferr_ap_decam_i'    / label for column 174
# TFORM174= 'D       '           / format for column 174
# TUNIT174= 'uJy     '           / units for column 174
# TTYPE175= 'm_decam_i'          / label for column 175
# TFORM175= 'D       '           / format for column 175
# TUNIT175= 'mag     '           / units for column 175
# TTYPE176= 'merr_decam_i'       / label for column 176
# TFORM176= 'D       '           / format for column 176
# TUNIT176= 'mag     '           / units for column 176
# TTYPE177= 'm_ap_decam_i'       / label for column 177
# TFORM177= 'D       '           / format for column 177
# TUNIT177= 'mag     '           / units for column 177
# TTYPE178= 'merr_ap_decam_i'    / label for column 178
# TFORM178= 'D       '           / format for column 178
# TUNIT178= 'mag     '           / units for column 178
# TTYPE179= 'flag_decam_i'       / label for column 179
# TFORM179= 'L       '           / format for column 179
# TTYPE180= 'f_acs_f814w'        / label for column 180
# TFORM180= 'D       '           / format for column 180
# TUNIT180= 'uJy     '           / units for column 180
# TTYPE181= 'ferr_acs_f814w'     / label for column 181
# TFORM181= 'D       '           / format for column 181
# TUNIT181= 'uJy     '           / units for column 181
# TTYPE182= 'f_ap_acs_f814w'     / label for column 182
# TFORM182= 'D       '           / format for column 182
# TUNIT182= 'uJy     '           / units for column 182
# TTYPE183= 'ferr_ap_acs_f814w'  / label for column 183
# TFORM183= 'D       '           / format for column 183
# TUNIT183= 'uJy     '           / units for column 183
# TTYPE184= 'm_acs_f814w'        / label for column 184
# TFORM184= 'D       '           / format for column 184
# TUNIT184= 'mag     '           / units for column 184
# TTYPE185= 'merr_acs_f814w'     / label for column 185
# TFORM185= 'D       '           / format for column 185
# TUNIT185= 'mag     '           / units for column 185
# TTYPE186= 'm_ap_acs_f814w'     / label for column 186
# TFORM186= 'D       '           / format for column 186
# TUNIT186= 'mag     '           / units for column 186
# TTYPE187= 'merr_ap_acs_f814w'  / label for column 187
# TFORM187= 'D       '           / format for column 187
# TUNIT187= 'mag     '           / units for column 187
# TTYPE188= 'flag_acs_f814w'     / label for column 188
# TFORM188= 'L       '           / format for column 188
# TTYPE189= 'f_suprime_n816'     / label for column 189
# TFORM189= 'D       '           / format for column 189
# TUNIT189= 'uJy     '           / units for column 189
# TTYPE190= 'ferr_suprime_n816'  / label for column 190
# TFORM190= 'D       '           / format for column 190
# TUNIT190= 'uJy     '           / units for column 190
# TTYPE191= 'f_ap_suprime_n816'  / label for column 191
# TFORM191= 'D       '           / format for column 191
# TUNIT191= 'uJy     '           / units for column 191
# TTYPE192= 'ferr_ap_suprime_n816' / label for column 192
# TFORM192= 'D       '           / format for column 192
# TUNIT192= 'uJy     '           / units for column 192
# TTYPE193= 'm_suprime_n816'     / label for column 193
# TFORM193= 'D       '           / format for column 193
# TUNIT193= 'mag     '           / units for column 193
# TTYPE194= 'merr_suprime_n816'  / label for column 194
# TFORM194= 'D       '           / format for column 194
# TUNIT194= 'mag     '           / units for column 194
# TTYPE195= 'm_ap_suprime_n816'  / label for column 195
# TFORM195= 'D       '           / format for column 195
# TUNIT195= 'mag     '           / units for column 195
# TTYPE196= 'merr_ap_suprime_n816' / label for column 196
# TFORM196= 'D       '           / format for column 196
# TUNIT196= 'mag     '           / units for column 196
# TTYPE197= 'flag_suprime_n816'  / label for column 197
# TFORM197= 'L       '           / format for column 197
# TTYPE198= 'f_suprime_zp'       / label for column 198
# TFORM198= 'D       '           / format for column 198
# TUNIT198= 'uJy     '           / units for column 198
# TTYPE199= 'ferr_suprime_zp'    / label for column 199
# TFORM199= 'D       '           / format for column 199
# TUNIT199= 'uJy     '           / units for column 199
# TTYPE200= 'f_ap_suprime_zp'    / label for column 200
# TFORM200= 'D       '           / format for column 200
# TUNIT200= 'uJy     '           / units for column 200
# TTYPE201= 'ferr_ap_suprime_zp' / label for column 201
# TFORM201= 'D       '           / format for column 201
# TUNIT201= 'uJy     '           / units for column 201
# TTYPE202= 'm_suprime_zp'       / label for column 202
# TFORM202= 'D       '           / format for column 202
# TUNIT202= 'mag     '           / units for column 202
# TTYPE203= 'merr_suprime_zp'    / label for column 203
# TFORM203= 'D       '           / format for column 203
# TUNIT203= 'mag     '           / units for column 203
# TTYPE204= 'm_ap_suprime_zp'    / label for column 204
# ...
# TUNIT403= 'uJy     '           / units for column 403
# TTYPE404= 'ferr_ap_irac_i1'    / label for column 404
# TFORM404= 'D       '           / format for column 404
# TUNIT404= 'uJy     '           / units for column 404
# TTYPE405= 'm_irac_i1'          / label for column 405
# TFORM405= 'D       '           / format for column 405
# TUNIT405= 'mag     '           / units for column 405
# TTYPE406= 'merr_irac_i1'       / label for column 406
# TFORM406= 'D       '           / format for column 406
# TUNIT406= 'mag     '           / units for column 406
# TTYPE407= 'm_ap_irac_i1'       / label for column 407
# TFORM407= 'D       '           / format for column 407
# TUNIT407= 'mag     '           / units for column 407
# TTYPE408= 'merr_ap_irac_i1'    / label for column 408
# TFORM408= 'D       '           / format for column 408
# TUNIT408= 'mag     '           / units for column 408
# TTYPE409= 'flag_irac_i1'       / label for column 409
# TFORM409= 'L       '           / format for column 409
# TTYPE410= 'f_irac_i2'          / label for column 410
# TFORM410= 'D       '           / format for column 410
# TUNIT410= 'uJy     '           / units for column 410
# TTYPE411= 'ferr_irac_i2'       / label for column 411
# TFORM411= 'D       '           / format for column 411
# TUNIT411= 'uJy     '           / units for column 411
# TTYPE412= 'f_ap_irac_i2'       / label for column 412
# TFORM412= 'D       '           / format for column 412
# TUNIT412= 'uJy     '           / units for column 412
# TTYPE413= 'ferr_ap_irac_i2'    / label for column 413
# TFORM413= 'D       '           / format for column 413
# TUNIT413= 'uJy     '           / units for column 413
# TTYPE414= 'm_irac_i2'          / label for column 414
# TFORM414= 'D       '           / format for column 414
# TUNIT414= 'mag     '           / units for column 414
# TTYPE415= 'merr_irac_i2'       / label for column 415
# TFORM415= 'D       '           / format for column 415
# TUNIT415= 'mag     '           / units for column 415
# TTYPE416= 'm_ap_irac_i2'       / label for column 416
# TFORM416= 'D       '           / format for column 416
# TUNIT416= 'mag     '           / units for column 416
# TTYPE417= 'merr_ap_irac_i2'    / label for column 417
# TFORM417= 'D       '           / format for column 417
# TUNIT417= 'mag     '           / units for column 417
# TTYPE418= 'flag_irac_i2'       / label for column 418
# TFORM418= 'L       '           / format for column 418
# TTYPE419= 'f_irac_i3'          / label for column 419
# TFORM419= 'D       '           / format for column 419
# TUNIT419= 'uJy     '           / units for column 419
# TTYPE420= 'ferr_irac_i3'       / label for column 420
# TFORM420= 'D       '           / format for column 420
# TUNIT420= 'uJy     '           / units for column 420
# TTYPE421= 'f_ap_irac_i3'       / label for column 421
# TFORM421= 'D       '           / format for column 421
# TUNIT421= 'uJy     '           / units for column 421
# TTYPE422= 'ferr_ap_irac_i3'    / label for column 422
# TFORM422= 'D       '           / format for column 422
# TUNIT422= 'uJy     '           / units for column 422
# TTYPE423= 'm_irac_i3'          / label for column 423
# TFORM423= 'D       '           / format for column 423
# TUNIT423= 'mag     '           / units for column 423
# TTYPE424= 'merr_irac_i3'       / label for column 424
# TFORM424= 'D       '           / format for column 424
# TUNIT424= 'mag     '           / units for column 424
# TTYPE425= 'm_ap_irac_i3'       / label for column 425
# TFORM425= 'D       '           / format for column 425
# TUNIT425= 'mag     '           / units for column 425
# TTYPE426= 'merr_ap_irac_i3'    / label for column 426
# TFORM426= 'D       '           / format for column 426
# TUNIT426= 'mag     '           / units for column 426
# TTYPE427= 'flag_irac_i3'       / label for column 427
# TFORM427= 'L       '           / format for column 427
# TTYPE428= 'f_irac_i4'          / label for column 428
# TFORM428= 'D       '           / format for column 428
# TUNIT428= 'uJy     '           / units for column 428
# TTYPE429= 'ferr_irac_i4'       / label for column 429
# TFORM429= 'D       '           / format for column 429
# TUNIT429= 'uJy     '           / units for column 429
# TTYPE430= 'f_ap_irac_i4'       / label for column 430
# TFORM430= 'D       '           / format for column 430
# TUNIT430= 'uJy     '           / units for column 430
# TTYPE431= 'ferr_ap_irac_i4'    / label for column 431
# TFORM431= 'D       '           / format for column 431
# TUNIT431= 'uJy     '           / units for column 431
# TTYPE432= 'm_irac_i4'          / label for column 432
# TFORM432= 'D       '           / format for column 432
# TUNIT432= 'mag     '           / units for column 432
# TTYPE433= 'merr_irac_i4'       / label for column 433
# TFORM433= 'D       '           / format for column 433
# TUNIT433= 'mag     '           / units for column 433
# TTYPE434= 'm_ap_irac_i4'       / label for column 434
# TFORM434= 'D       '           / format for column 434
# TUNIT434= 'mag     '           / units for column 434
# TTYPE435= 'merr_ap_irac_i4'    / label for column 435
# TFORM435= 'D       '           / format for column 435
# TUNIT435= 'mag     '           / units for column 435
# TTYPE436= 'flag_irac_i4'       / label for column 436
# TFORM436= 'L       '           / format for column 436
# TTYPE437= 'f_mips_24'          / label for column 437
# TFORM437= 'E       '           / format for column 437
# TUNIT437= 'uJy     '           / units for column 437
# TTYPE438= 'ferr_mips_24'       / label for column 438
# TFORM438= 'E       '           / format for column 438
# TUNIT438= 'uJy     '           / units for column 438
# TTYPE439= 'flag_mips_24'       / label for column 439
# TFORM439= 'L       '           / format for column 439
# TTYPE440= 'f_pacs_green'       / label for column 440
# TFORM440= 'E       '           / format for column 440
# TUNIT440= 'uJy     '           / units for column 440
# TTYPE441= 'ferr_pacs_green'    / label for column 441
# TFORM441= 'E       '           / format for column 441
# TUNIT441= 'uJy     '           / units for column 441
# TTYPE442= 'flag_pacs_green'    / label for column 442
# TFORM442= 'L       '           / format for column 442
# TTYPE443= 'f_pacs_red'         / label for column 443
# TFORM443= 'E       '           / format for column 443
# TUNIT443= 'uJy     '           / units for column 443
# TTYPE444= 'ferr_pacs_red'      / label for column 444
# TFORM444= 'E       '           / format for column 444
# TUNIT444= 'uJy     '           / units for column 444
# TTYPE445= 'flag_pacs_red'      / label for column 445
# TFORM445= 'L       '           / format for column 445
# TTYPE446= 'f_spire_250'        / label for column 446
# TFORM446= 'E       '           / format for column 446
# TUNIT446= 'uJy     '           / units for column 446
# TTYPE447= 'ferr_spire_250'     / label for column 447
# TFORM447= 'E       '           / format for column 447
# TUNIT447= 'uJy     '           / units for column 447
# TTYPE448= 'flag_spire_250'     / label for column 448
# TFORM448= 'L       '           / format for column 448
# TTYPE449= 'f_spire_350'        / label for column 449
# TFORM449= 'E       '           / format for column 449
# TUNIT449= 'uJy     '           / units for column 449
# TTYPE450= 'ferr_spire_350'     / label for column 450
# TFORM450= 'E       '           / format for column 450
# TUNIT450= 'uJy     '           / units for column 450
# TTYPE451= 'flag_spire_350'     / label for column 451
# TFORM451= 'L       '           / format for column 451
# TTYPE452= 'f_spire_500'        / label for column 452
# TFORM452= 'E       '           / format for column 452
# TUNIT452= 'uJy     '           / units for column 452
# TTYPE453= 'ferr_spire_500'     / label for column 453
# TFORM453= 'E       '           / format for column 453
# TUNIT453= 'uJy     '           / units for column 453
# TTYPE454= 'flag_spire_500'     / label for column 454
# TFORM454= 'L       '           / format for column 454
# TTYPE455= 'cigale_mstar'       / label for column 455
# TFORM455= 'D       '           / format for column 455
# TUNIT455= 'solMass '           / units for column 455
# TTYPE456= 'cigale_mstar_err'   / label for column 456
# TFORM456= 'D       '           / format for column 456
# TUNIT456= 'solMass '           / units for column 456
# TTYPE457= 'cigale_sfr'         / label for column 457
# TFORM457= 'D       '           / format for column 457
# TUNIT457= 'solMass yr-1'       / units for column 457
# TTYPE458= 'cigale_sfr_err'     / label for column 458
# TFORM458= 'D       '           / format for column 458
# TUNIT458= 'solMass yr-1'       / units for column 458
# TTYPE459= 'cigale_dustlumin'   / label for column 459
# TFORM459= 'D       '           / format for column 459
# TUNIT459= 'W       '           / units for column 459
# TTYPE460= 'cigale_dustlumin_err' / label for column 460
# TFORM460= 'D       '           / format for column 460
# TUNIT460= 'W       '           / units for column 460
# TTYPE461= 'cigale_dustlumin_ironly' / label for column 461
# TFORM461= 'D       '           / format for column 461
# TUNIT461= 'W       '           / units for column 461
# TTYPE462= 'cigale_dustlumin_ironly_err' / label for column 462
# TFORM462= 'D       '           / format for column 462
# TUNIT462= 'W       '           / units for column 462
# TTYPE463= 'flag_cigale'        / label for column 463
# TFORM463= 'K       '           / format for column 463
# TTYPE464= 'flag_cigale_opt'    / label for column 464
# TFORM464= 'K       '           / format for column 464
# TTYPE465= 'flag_cigale_ir'     / label for column 465
# TFORM465= 'K       '           / format for column 465
# TTYPE466= 'flag_cigale_ironly' / label for column 466
# TFORM466= 'K       '           / format for column 466
# TTYPE467= 'stellarity'         / label for column 467
# TFORM467= 'D       '           / format for column 467
# TTYPE468= 'stellarity_origin'  / label for column 468
# TFORM468= '20A     '           / format for column 468
# TTYPE469= 'flag_cleaned'       / label for column 469
# TFORM469= 'L       '           / format for column 469
# TTYPE470= 'flag_merged'        / label for column 470
# TFORM470= 'L       '           / format for column 470
# TTYPE471= 'flag_gaia'          / label for column 471
# TFORM471= 'K       '           / format for column 471
# TTYPE472= 'flag_optnir_obs'    / label for column 472
# TFORM472= 'K       '           / format for column 472
# TTYPE473= 'flag_optnir_det'    / label for column 473
# TFORM473= 'K       '           / format for column 473
# TTYPE474= 'zspec_qual'         / label for column 474
# TFORM474= 'K       '           / format for column 474
# TTYPE475= 'zspec_association_flag' / label for column 475
# TFORM475= 'L       '           / format for column 475
# DATE-HDU= '2019-03-29T10:43:39' / Date of HDU creation (UTC)
# STILVERS= '3.2-2   '           / Version of STIL software
# STILCLAS= 'uk.ac.starlink.votable.FitsPlusTableWriter' / Author class in STIL so

# %%
# catalog = table.Table.read('./data/SWIRE_and_XSERVS.fits')
file = './data/master_catalogue_xmm-lss_20180221_photoz_20180518_r_optimised.fits'
catalog = table.Table.read(file)
print(len(catalog))
catalog[0]
catalog = table.Table.read('./data/XMM-LSS_20190328.fits')
# Out:
# 6152920

# %%
flux36 = 'F_CH1'
flux45 = 'F_CH2'
flux58 = 'flux_ap2_58'
flux80 = 'flux_ap2_80'
# print(catalog[flux58][catalog[flux58] < 0])
never_nan = (np.nan_to_num(catalog[flux58], nan=-99) > 0) & (np.nan_to_num(catalog[flux80], nan=-99) > 0)
fig, axs = sc.plot_wedge(catalog[never_nan], flux36, flux45, flux58, flux80, selection=['lacy05', 'stern05', 'donley12'])
selected_agn = sc.select_ir(catalog[never_nan], flux36, flux45, flux58, flux80, selection_cuts='lacy05')

# %% [markdown]
# detection80 = np.nan_to_num(catalog[flux80], nan=-99) > 0
# plt.scatter(catalog[detection80]['RA_1'], catalog[detection80]['DEC_1'], s=1, alpha=0.1)

# %%
print(np.sum(never_nan), len(selected_agn))
ct_lacy = catalog[never_nan][selected_agn]

# %%
cosmo = af.setup_cosmology()
print(len(ct_lacy))

ct_lacy = ct_lacy[(ct_lacy['z_eazy'] > 0 ) | (ct_lacy['zSpec'] > 0)]
# ct_lacy = ct_lacy[ct_lacy['z_eazy'] > 0]
print(len(ct_lacy))

import astropy.units as u

spectral_index = 1.5

# unit conversion: ujansky -> jansky: 1e-6
# jansky -> erg / s / cm**2 / Hz: 1e-23
# erg / s / Hz -> erg / s: nu = c/lambda = 3e8 / 3.6e-6
unit_conversion = 1e-6 * 1e-23 * 3e8 / 3.6e-6 * (3.086e24)**2
unit_conversion = 3 / 3.6 * 3.086**2 * 1e33
# print(unit_conversion)

z = np.array([row['zSpec'] if row['zSpec'] > 0 else row['z_eazy'] for row in ct_lacy])
# z = ct_lacy['z_eazy']
ldist = cosmo.luminosity_distance(z).value**2
# print(ldist)
l = 4 * np.pi * cosmo.luminosity_distance(z).value**2 * ct_lacy[flux58] * unit_conversion / (1 + z)**(1 + spectral_index)
# print(l)
print(np.log10(l))

# %%
print(min(l), max(l), min(z), max(z))
z_sample_min = 0.5
z_sample_max = 4
l_sample_min = 3e42
l_sample_max = 3e46

good_redshift_and_l_selected = (l_sample_min < l) & (l_sample_max > l) & (z_sample_min < z) & (z_sample_max > z)
l = l[good_redshift_and_l_selected]
z = z[good_redshift_and_l_selected]
print(len(z))

# %%
num_bins_z = 10
num_bins_l = 12
# redshift range 
z_bins = np.logspace(np.log10(z_sample_min)-0.01, np.log10(z_sample_max)+0.01, num=num_bins_z)
print(z_bins)
l_bins = np.logspace(np.log10(l_sample_min), np.log10(l_sample_max), num=num_bins_l)

# print(len(z))
fig, ax = vmax.l_z_histo(l, z, l_bins, z_bins, band='2-10 keV X-ray', unit=r'erg s$^{-1}$')

# %%
image_file = './data/swire_XMM_I3_tile_1_1_v4_cov.fits'
wcs, hdu = utils.load_wcs(image_file)
fig, ax = vmax.exposure_plot(wcs, hdu.data, survey='SWIRE', band='IRAC 3')

# %%
# flux_limit = 5 * unit_conversion
flux_limit = 3631 * 10**(23/-2.5) * 5.8e-6 / 3e8
print(flux_limit)
zmax = vmax.compute_zmax(l, z, cosmo, flux_limit, zspacing=0.5)
zmin = np.array([0]*len(zmax))

full_fluxes = catalog[never_nan][flux58]
# print(len(full_fluxes), len(ct_lacy), len(good_redshift_and_l_selected))
coverage_correction = vmax.coverage_correction(full_fluxes, ct_lacy[flux58][good_redshift_and_l_selected])

# image_file = './data/chen2018-xmmlss-data-products-2018-06-08/xexp_merged.full.v01.fits'
# wcs, hdu = utils.load_wcs(image_file)
# cov_function = vmax.coverage_function(hdu.data, wcs, 3824, 2694, detector_area=36, photon_energy=7e-9)

def cov_func(l, z): 
    flux = l / (4 * np.pi * cosmo.luminosity_distance(z).value**2)
# #     print(flux[0, 0], cov_function(flux[0, 0]))
    return 4.8 * coverage_correction(flux / unit_conversion)

print('here')
vmax_vals = vmax.compute_binned_vmax_values(l, (z, zmin, zmax), l_bins, z_bins, cosmo, bin_z_bounds=False, coverage=cov_func)

# %%
zs = (z_bins[:-1]+z_bins[1:])/2
l_limits = 4 * np.pi * cosmo.luminosity_distance(zs).to(u.cm).value**2 * flux_limit / (1 + zs)**(1 + spectral_index)
print(l_limits)
lf_vals, lf_errs = vmax.compute_lf_values(l, z, vmax_vals, z_bins, l_bins)

# %%
lit_data = {}
hz_convert = 5.8e-6 / 3e8
import importlib
importlib.reload(af)

lacy_ir_evol_params_central = {'A': 10**-4.75, 
                               'gamma1':1.07, 
                               'gamma2':2.48,
                               'Lstar': 10**31.92 / hz_convert,
                               'zref':2.5,
                               'k1':1.05,
                               'k2':-4.71,
                               'k3':-0.034
                              }
lacy_ir_evol_params_max = {'A': 10**-4.73, 
                               'gamma1':1.13, 
                               'gamma2':2.53,
                               'Lstar': 10**31.94 / hz_convert,
                               'zref':2.5,
                               'k1':1.08,
                               'k2':-4.58,
                               'k3':0.156
                              }
lacy_ir_evol_params_min = {'A': 10**-4.77, 
                               'gamma1':1.01, 
                               'gamma2':2.43,
                               'Lstar': 10**31.9 / hz_convert,
                               'zref':2.5,
                               'k1':1.02,
                               'k2':-4.84,
                               'k3':-0.224
                              }

center_zbins = (z_bins[1:] + z_bins[:-1]) / 2
ls = np.logspace(43, 46.2, num=50)
lacy_mid = af.IR_evol(ls, center_zbins, **lacy_ir_evol_params_central)
lacy_high = af.IR_evol(ls, center_zbins, **lacy_ir_evol_params_max)
lacy_low = af.IR_evol(ls, center_zbins, **lacy_ir_evol_params_min)
# print(lacy_mid[0])
lit_data['Lacy 2015'] = list(zip(lacy_mid, lacy_high, lacy_low))
# lacy_mid[1][:10]

# %%
fig, axs, big_ax = vmax.plot_lf_vmax(lf_vals, lf_errs, z_bins, l_bins, \
                                     lum_limits=l_limits, compare_to_others=lit_data, \
                                     title=r'LF for 5.8 $\mu$m', \
                                     outfile='./output/ir_lf.png', lum_sublabel='_{{5.8}}')

# %%
from astropy import cosmology

# %%
greene = cosmology.LambdaCDM(H0=71, Om0=0.27, Ode0=0.75)
farrah = cosmology.LambdaCDM(H0=70, Om0=0.3, Ode0=0.7)
medling = cosmology.LambdaCDM(H0=70, Om0=0.28, Ode0=0.72)

# %%
z=1
farrah.luminosity_distance(z)**2/greene.luminosity_distance(z)**2, farrah.luminosity_distance(z)**2/medling.luminosity_distance(z)**2
