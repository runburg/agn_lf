# %%
# %cd ~/github/agn_lf/
# Out:
# /Users/runburg/github/agn_lf

# %%
import source.astro_functions as af
import source.table_functions as tf
import source.lf_xi2 as xi2
import source.lf_vmax as vmax
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import astropy.table as table
# flagged_agn = table.Table.read('./data/flagged_agn.fits')

# %%
catalog = fits.open("./data/SWIRE_and_XSERVS.fits", memmap=True)

# %%
catalog[1].columns
# Out:
# ColDefs(
#     name = 'cntr'; format = 'J'; null = -2147483648
#     name = 'object'; format = '30A'
#     name = 'ra_1'; format = 'D'; unit = 'deg'
#     name = 'dec_1'; format = 'D'; unit = 'deg'
#     name = 'unc_ra'; format = 'D'; unit = 'arcsec'
#     name = 'unc_dec'; format = 'D'; unit = 'arcsec'
#     name = 'tile'; format = 'J'; null = -2147483648
#     name = 'flux_ap2_36'; format = 'D'; unit = 'ujy'
#     name = 'uncf_ap2_36'; format = 'D'; unit = 'ujy'
#     name = 'flux_kr_36'; format = 'D'; unit = 'ujy'
#     name = 'uncf_kr_36'; format = 'D'; unit = 'ujy'
#     name = 'stell_36'; format = 'D'
#     name = 'flgs_36'; format = '9A'
#     name = 'ext_fl_36'; format = 'J'; null = -2147483648
#     name = 'flux_ap2_45'; format = 'D'; unit = 'ujy'
#     name = 'uncf_ap2_45'; format = 'D'; unit = 'ujy'
#     name = 'flux_kr_45'; format = 'D'; unit = 'ujy'
#     name = 'uncf_kr_45'; format = 'D'; unit = 'ujy'
#     name = 'stell_45'; format = 'D'
#     name = 'flgs_45'; format = '9A'
#     name = 'ext_fl_45'; format = 'J'; null = -2147483648
#     name = 'flux_ap2_58'; format = 'D'; unit = 'ujy'
#     name = 'uncf_ap2_58'; format = 'D'; unit = 'ujy'
#     name = 'flux_kr_58'; format = 'D'; unit = 'ujy'
#     name = 'uncf_kr_58'; format = 'D'; unit = 'ujy'
#     name = 'stell_58'; format = 'D'
#     name = 'flgs_58'; format = '9A'
#     name = 'ext_fl_58'; format = 'J'; null = -2147483648
#     name = 'flux_ap2_80'; format = 'D'; unit = 'ujy'
#     name = 'uncf_ap2_80'; format = 'D'; unit = 'ujy'
#     name = 'flux_kr_80'; format = 'D'; unit = 'ujy'
#     name = 'uncf_kr_80'; format = 'D'; unit = 'ujy'
#     name = 'stell_80'; format = 'D'
#     name = 'flgs_80'; format = '9A'
#     name = 'ext_fl_80'; format = 'J'; null = -2147483648
#     name = 'flux_ap2_24'; format = 'D'; unit = 'ujy'
#     name = 'uncf_ap2_24'; format = 'D'; unit = 'ujy'
#     name = 'flux_kr_24'; format = 'D'; unit = 'ujy'
#     name = 'uncf_kr_24'; format = 'D'; unit = 'ujy'
#     name = 'stell_24'; format = 'D'
#     name = 'flgs_24'; format = '9A'
#     name = 'ext_fl_24'; format = 'J'; null = -2147483648
#     name = 'XID'; format = '8A'
#     name = 'RA_2'; format = 'D'
#     name = 'DEC_2'; format = 'D'
#     name = 'XPOSERR'; format = 'D'
#     name = 'R68'; format = 'D'
#     name = 'R99'; format = 'D'
#     name = 'EMLERR'; format = 'D'
#     name = 'SB_RA'; format = 'D'
#     name = 'SB_DEC'; format = 'D'
#     name = 'HB_RA'; format = 'D'
#     name = 'HB_DEC'; format = 'D'
#     name = 'FB_RA'; format = 'D'
#     name = 'FB_DEC'; format = 'D'
#     name = 'SB_DET_ML'; format = 'D'
#     name = 'HB_DET_ML'; format = 'D'
#     name = 'FB_DET_ML'; format = 'D'
#     name = 'SB_RELIABILITY'; format = 'E'
#     name = 'HB_RELIABILITY'; format = 'E'
#     name = 'FB_RELIABILITY'; format = 'E'
#     name = 'SB_EXP'; format = 'D'
#     name = 'HB_EXP'; format = 'D'
#     name = 'FB_EXP'; format = 'D'
#     name = 'SB_EXPPN'; format = 'D'
#     name = 'SB_EXPM1'; format = 'D'
#     name = 'SB_EXPM2'; format = 'D'
#     name = 'HB_EXPPN'; format = 'D'
#     name = 'HB_EXPM1'; format = 'D'
#     name = 'HB_EXPM2'; format = 'D'
#     name = 'FB_EXPPN'; format = 'D'
#     name = 'FB_EXPM1'; format = 'D'
#     name = 'FB_EXPM2'; format = 'D'
#     name = 'SB_BKG'; format = 'D'
#     name = 'HB_BKG'; format = 'D'
#     name = 'FB_BKG'; format = 'D'
#     name = 'SB_BKGPN'; format = 'D'
#     name = 'SB_BKGM1'; format = 'D'
#     name = 'SB_BKGM2'; format = 'D'
#     name = 'HB_BKGPN'; format = 'D'
#     name = 'HB_BKGM1'; format = 'D'
#     name = 'HB_BKGM2'; format = 'D'
#     name = 'FB_BKGPN'; format = 'D'
#     name = 'FB_BKGM1'; format = 'D'
#     name = 'FB_BKGM2'; format = 'D'
#     name = 'SB_SCTS'; format = 'D'
#     name = 'HB_SCTS'; format = 'D'
#     name = 'FB_SCTS'; format = 'D'
#     name = 'SB_SCTPN'; format = 'D'
#     name = 'SB_SCTM1'; format = 'D'
#     name = 'SB_SCTM2'; format = 'D'
#     name = 'HB_SCTPN'; format = 'D'
#     name = 'HB_SCTM1'; format = 'D'
#     name = 'HB_SCTM2'; format = 'D'
#     name = 'FB_SCTPN'; format = 'D'
#     name = 'FB_SCTM1'; format = 'D'
#     name = 'FB_SCTM2'; format = 'D'
#     name = 'SB_SCTS_ERR'; format = 'D'
#     name = 'HB_SCTS_ERR'; format = 'D'
#     name = 'FB_SCTS_ERR'; format = 'D'
#     name = 'SB_SCTPN_ERR'; format = 'D'
#     name = 'SB_SCTM1_ERR'; format = 'D'
#     name = 'SB_SCTM2_ERR'; format = 'D'
#     name = 'HB_SCTPN_ERR'; format = 'D'
#     name = 'HB_SCTM1_ERR'; format = 'D'
#     name = 'HB_SCTM2_ERR'; format = 'D'
#     name = 'FB_SCTPN_ERR'; format = 'D'
#     name = 'FB_SCTM1_ERR'; format = 'D'
#     name = 'FB_SCTM2_ERR'; format = 'D'
#     name = 'SB_RATE'; format = 'D'
#     name = 'SB_RATEPN'; format = 'D'
#     name = 'SB_RATEM1'; format = 'D'
#     name = 'SB_RATEM2'; format = 'D'
#     name = 'HB_RATE'; format = 'D'
#     name = 'HB_RATEPN'; format = 'D'
#     name = 'HB_RATEM1'; format = 'D'
#     name = 'HB_RATEM2'; format = 'D'
#     name = 'FB_RATE'; format = 'D'
#     name = 'FB_RATEPN'; format = 'D'
#     name = 'FB_RATEM1'; format = 'D'
#     name = 'FB_RATEM2'; format = 'D'
#     name = 'SB_RATE_ERR'; format = 'D'
#     name = 'SB_RATEPN_ERR'; format = 'D'
#     name = 'SB_RATEM1_ERR'; format = 'D'
#     name = 'SB_RATEM2_ERR'; format = 'D'
#     name = 'HB_RATE_ERR'; format = 'D'
#     name = 'HB_RATEPN_ERR'; format = 'D'
#     name = 'HB_RATEM1_ERR'; format = 'D'
#     name = 'HB_RATEM2_ERR'; format = 'D'
#     name = 'FB_RATE_ERR'; format = 'D'
#     name = 'FB_RATEPN_ERR'; format = 'D'
#     name = 'FB_RATEM1_ERR'; format = 'D'
#     name = 'FB_RATEM2_ERR'; format = 'D'
#     name = 'SB_FLUX'; format = 'D'
#     name = 'SB_FLUXERR'; format = 'D'
#     name = 'HB_FLUX'; format = 'D'
#     name = 'HB_FLUXERR'; format = 'D'
#     name = 'FB_FLUX'; format = 'D'
#     name = 'FB_FLUXERR'; format = 'D'
#     name = 'HR'; format = 'D'
#     name = 'HR_LERR'; format = 'D'
#     name = 'HR_UERR'; format = 'D'
#     name = 'BEHR_PN'; format = 'D'
#     name = 'BEHR_LB_PN'; format = 'D'
#     name = 'BEHR_UB_PN'; format = 'D'
#     name = 'BEHR_M1'; format = 'D'
#     name = 'BEHR_LB_M1'; format = 'D'
#     name = 'BEHR_UB_M1'; format = 'D'
#     name = 'BEHR_M2'; format = 'D'
#     name = 'BEHR_LB_M2'; format = 'D'
#     name = 'BEHR_UB_M2'; format = 'D'
#     name = 'LX'; format = 'D'
#     name = 'CSCID'; format = '29A'
#     name = 'XXLID'; format = '8A'
#     name = 'NALL_SERVS'; format = 'E'
#     name = 'NALL_VIDEO'; format = 'E'
#     name = 'NALL_CFHT'; format = 'E'
#     name = 'NALL_HSC'; format = 'E'
#     name = 'NMATCH_LR_SERVS'; format = 'E'
#     name = 'NMATCH_LR_VIDEO'; format = 'E'
#     name = 'NMATCH_LR_CFHT'; format = 'E'
#     name = 'NMATCH_LR_HSC'; format = 'E'
#     name = 'LR_RELIABLE'; format = 'I'; null = -32768
#     name = 'SERVS_BLENDING'; format = 'I'; null = -32768
#     name = 'CATALOG'; format = '6A'
#     name = 'OIR_RA'; format = 'D'
#     name = 'OIR_DEC'; format = 'D'
#     name = 'XOIR_SEP'; format = 'D'
#     name = 'LR'; format = 'D'
#     name = 'SERVS_RA'; format = 'D'
#     name = 'SERVS_DEC'; format = 'D'
#     name = 'SERVS_ID'; format = 'D'
#     name = 'SERVS_MR'; format = 'D'
#     name = 'VIDEO_RA'; format = 'D'
#     name = 'VIDEO_DEC'; format = 'D'
#     name = 'VIDEO_ID'; format = 'K'; null = -9223372036854775808
#     name = 'VIDEO_MR'; format = 'D'
#     name = 'CFHT_RA'; format = 'D'
#     name = 'CFHT_DEC'; format = 'D'
#     name = 'CFHT_ID'; format = '11A'
#     name = 'CFHT_MR'; format = 'D'
#     name = 'HSC_RA'; format = 'D'
#     name = 'HSC_DEC'; format = 'D'
#     name = 'HSC_ID'; format = 'K'; null = -9223372036854775808
#     name = 'HSC_MR'; format = 'D'
#     name = 'SERVS_MAG1'; format = 'D'
#     name = 'SERVS_MAG2'; format = 'D'
#     name = 'SERVS_MAG1_ERR'; format = 'D'
#     name = 'SERVS_MAG2_ERR'; format = 'D'
#     name = 'SWIRE_MAG1'; format = 'D'
#     name = 'SWIRE_MAG2'; format = 'D'
#     name = 'SWIRE_MAG3'; format = 'D'
#     name = 'SWIRE_MAG4'; format = 'D'
#     name = 'SWIRE_MAG1_ERR'; format = 'D'
#     name = 'SWIRE_MAG2_ERR'; format = 'D'
#     name = 'SWIRE_MAG3_ERR'; format = 'D'
#     name = 'SWIRE_MAG4_ERR'; format = 'D'
#     name = 'SWIRE_MIPS24'; format = 'D'
#     name = 'SWIRE_MIPS24_ERR'; format = 'D'
#     name = 'VIDEO_ZMAG'; format = 'D'
#     name = 'VIDEO_ZMAGERR'; format = 'D'
#     name = 'VIDEO_YMAG'; format = 'D'
#     name = 'VIDEO_YMAGERR'; format = 'D'
#     name = 'VIDEO_JMAG'; format = 'D'
#     name = 'VIDEO_JMAGERR'; format = 'D'
#     name = 'VIDEO_HMAG'; format = 'D'
#     name = 'VIDEO_HMAGERR'; format = 'D'
#     name = 'VIDEO_KSMAG'; format = 'D'
#     name = 'VIDEO_KSMAGERR'; format = 'D'
#     name = 'CFHT_UMAG'; format = 'E'
#     name = 'CFHT_UMAGERR'; format = 'E'
#     name = 'CFHT_GMAG'; format = 'E'
#     name = 'CFHT_GMAGERR'; format = 'E'
#     name = 'CFHT_RMAG'; format = 'E'
#     name = 'CFHT_RMAGERR'; format = 'E'
#     name = 'CFHT_IMAG'; format = 'E'
#     name = 'CFHT_IMAGERR'; format = 'E'
#     name = 'CFHT_ZMAG'; format = 'E'
#     name = 'CFHT_ZMAGERR'; format = 'E'
#     name = 'HSC_GMAG'; format = 'D'
#     name = 'HSC_GMAGERR'; format = 'D'
#     name = 'HSC_RMAG'; format = 'D'
#     name = 'HSC_RMAGERR'; format = 'D'
#     name = 'HSC_IMAG'; format = 'D'
#     name = 'HSC_IMAGERR'; format = 'D'
#     name = 'HSC_ZMAG'; format = 'D'
#     name = 'HSC_ZMAGERR'; format = 'D'
#     name = 'HSC_YMAG'; format = 'D'
#     name = 'HSC_YMAGERR'; format = 'D'
#     name = 'ZSPEC_RA'; format = 'D'
#     name = 'ZSPEC_DEC'; format = 'D'
#     name = 'ZSPEC_ID'; format = '19A'
#     name = 'ZSPEC'; format = 'D'
#     name = 'ZSOURCE'; format = '6A'
#     name = 'ZOFLAG'; format = '18A'
#     name = 'ZPHOT'; format = 'E'
#     name = 'ZPHOT_UERR'; format = 'E'
#     name = 'ZPHOT_LERR'; format = 'E'
#     name = 'ZPHOT_QZ'; format = 'D'
#     name = 'CLASS'; format = 'J'; null = -2147483648
#     name = 'SECONDARY_CATALOG'; format = '13A'
#     name = 'SECONDARY_RA'; format = 'D'
#     name = 'SECONDARY_DEC'; format = 'D'
#     name = 'SECONDARY_SEP'; format = 'D'
#     name = 'SECONDARY_LR'; format = 'D'
#     name = 'SECONDARY_SERVS_RA'; format = 'D'
#     name = 'SECONDARY_SERVS_DEC'; format = 'D'
#     name = 'SECONDARY_SERVS_ID'; format = 'D'
#     name = 'SECONDARY_SERVS_MR'; format = 'D'
#     name = 'SECONDARY_VIDEO_RA'; format = 'D'
#     name = 'SECONDARY_VIDEO_DEC'; format = 'D'
#     name = 'SECONDARY_VIDEO_ID'; format = 'K'; null = -9223372036854775808
#     name = 'SECONDARY_VIDEO_MR'; format = 'D'
#     name = 'SECONDARY_CFHT_RA'; format = 'D'
#     name = 'SECONDARY_CFHT_DEC'; format = 'D'
#     name = 'SECONDARY_CFHT_ID'; format = '11A'
#     name = 'SECONDARY_CFHT_MR'; format = 'D'
#     name = 'SECONDARY_HSC_RA'; format = 'D'
#     name = 'SECONDARY_HSC_DEC'; format = 'D'
#     name = 'SECONDARY_HSC_ID'; format = 'K'; null = -9223372036854775808
#     name = 'SECONDARY_HSC_MR'; format = 'D'
#     name = 'SECONDARY_SERVS_MAG1'; format = 'D'
#     name = 'SECONDARY_SERVS_MAG2'; format = 'D'
#     name = 'SECONDARY_SERVS_MAG1_ERR'; format = 'D'
#     name = 'SECONDARY_SERVS_MAG2_ERR'; format = 'D'
#     name = 'SECONDARY_SWIRE_MAG1'; format = 'D'
#     name = 'SECONDARY_SWIRE_MAG2'; format = 'D'
#     name = 'SECONDARY_SWIRE_MAG3'; format = 'D'
#     name = 'SECONDARY_SWIRE_MAG4'; format = 'D'
#     name = 'SECONDARY_SWIRE_MAG1_ERR'; format = 'D'
#     name = 'SECONDARY_SWIRE_MAG2_ERR'; format = 'D'
#     name = 'SECONDARY_SWIRE_MAG3_ERR'; format = 'D'
#     name = 'SECONDARY_SWIRE_MAG4_ERR'; format = 'D'
#     name = 'SECONDARY_SWIRE_MIPS24'; format = 'D'
#     name = 'SECONDARY_SWIRE_MIPS24_ERR'; format = 'D'
#     name = 'SECONDARY_VIDEO_ZMAG'; format = 'D'
#     name = 'SECONDARY_VIDEO_ZMAGERR'; format = 'D'
#     name = 'SECONDARY_VIDEO_YMAG'; format = 'D'
#     name = 'SECONDARY_VIDEO_YMAGERR'; format = 'D'
#     name = 'SECONDARY_VIDEO_JMAG'; format = 'D'
#     name = 'SECONDARY_VIDEO_JMAGERR'; format = 'D'
#     name = 'SECONDARY_VIDEO_HMAG'; format = 'D'
#     name = 'SECONDARY_VIDEO_HMAGERR'; format = 'D'
#     name = 'SECONDARY_VIDEO_KSMAG'; format = 'D'
#     name = 'SECONDARY_VIDEO_KSMAGERR'; format = 'D'
#     name = 'SECONDARY_CFHT_UMAG'; format = 'E'
#     name = 'SECONDARY_CFHT_UMAGERR'; format = 'E'
#     name = 'SECONDARY_CFHT_GMAG'; format = 'E'
#     name = 'SECONDARY_CFHT_GMAGERR'; format = 'E'
#     name = 'SECONDARY_CFHT_RMAG'; format = 'E'
#     name = 'SECONDARY_CFHT_RMAGERR'; format = 'E'
#     name = 'SECONDARY_CFHT_IMAG'; format = 'E'
#     name = 'SECONDARY_CFHT_IMAGERR'; format = 'E'
#     name = 'SECONDARY_CFHT_ZMAG'; format = 'E'
#     name = 'SECONDARY_CFHT_ZMAGERR'; format = 'E'
#     name = 'SECONDARY_HSC_GMAG'; format = 'D'
#     name = 'SECONDARY_HSC_GMAGERR'; format = 'D'
#     name = 'SECONDARY_HSC_RMAG'; format = 'D'
#     name = 'SECONDARY_HSC_RMAGERR'; format = 'D'
#     name = 'SECONDARY_HSC_IMAG'; format = 'D'
#     name = 'SECONDARY_HSC_IMAGERR'; format = 'D'
#     name = 'SECONDARY_HSC_ZMAG'; format = 'D'
#     name = 'SECONDARY_HSC_ZMAGERR'; format = 'D'
#     name = 'SECONDARY_HSC_YMAG'; format = 'D'
#     name = 'SECONDARY_HSC_YMAGERR'; format = 'D'
#     name = 'SECONDARY_ZSPEC_RA'; format = 'D'
#     name = 'SECONDARY_ZSPEC_DEC'; format = 'D'
#     name = 'SECONDARY_ZSPEC_ID'; format = '19A'
#     name = 'SECONDARY_ZSPEC'; format = 'D'
#     name = 'SECONDARY_ZSOURCE'; format = '6A'
#     name = 'SECONDARY_ZOFLAG'; format = '18A'
#     name = 'TERTIARY_CATALOG'; format = '6A'
#     name = 'TERTIARY_RA'; format = 'D'
#     name = 'TERTIARY_DEC'; format = 'D'
#     name = 'TERTIARY_SEP'; format = 'D'
#     name = 'TERTIARY_LR'; format = 'D'
#     name = 'TERTIARY_SERVS_RA'; format = 'D'
#     name = 'TERTIARY_SERVS_DEC'; format = 'D'
#     name = 'TERTIARY_SERVS_ID'; format = 'D'
#     name = 'TERTIARY_SERVS_MR'; format = 'D'
#     name = 'TERTIARY_VIDEO_RA'; format = 'D'
#     name = 'TERTIARY_VIDEO_DEC'; format = 'D'
#     name = 'TERTIARY_VIDEO_ID'; format = 'K'; null = -9223372036854775808
#     name = 'TERTIARY_VIDEO_MR'; format = 'D'
#     name = 'TERTIARY_CFHT_RA'; format = 'D'
#     name = 'TERTIARY_CFHT_DEC'; format = 'D'
#     name = 'TERTIARY_CFHT_ID'; format = '11A'
#     name = 'TERTIARY_CFHT_MR'; format = 'D'
#     name = 'TERTIARY_HSC_RA'; format = 'D'
#     name = 'TERTIARY_HSC_DEC'; format = 'D'
#     name = 'TERTIARY_HSC_ID'; format = 'K'; null = -9223372036854775808
#     name = 'TERTIARY_HSC_MR'; format = 'D'
#     name = 'TERTIARY_SERVS_MAG1'; format = 'D'
#     name = 'TERTIARY_SERVS_MAG2'; format = 'D'
#     name = 'TERTIARY_SERVS_MAG1_ERR'; format = 'D'
#     name = 'TERTIARY_SERVS_MAG2_ERR'; format = 'D'
#     name = 'TERTIARY_SWIRE_MAG1'; format = 'D'
#     name = 'TERTIARY_SWIRE_MAG2'; format = 'D'
#     name = 'TERTIARY_SWIRE_MAG3'; format = 'D'
#     name = 'TERTIARY_SWIRE_MAG4'; format = 'D'
#     name = 'TERTIARY_SWIRE_MAG1_ERR'; format = 'D'
#     name = 'TERTIARY_SWIRE_MAG2_ERR'; format = 'D'
#     name = 'TERTIARY_SWIRE_MAG3_ERR'; format = 'D'
#     name = 'TERTIARY_SWIRE_MAG4_ERR'; format = 'D'
#     name = 'TERTIARY_SWIRE_MIPS24'; format = 'D'
#     name = 'TERTIARY_SWIRE_MIPS24_ERR'; format = 'D'
#     name = 'TERTIARY_VIDEO_ZMAG'; format = 'D'
#     name = 'TERTIARY_VIDEO_ZMAGERR'; format = 'D'
#     name = 'TERTIARY_VIDEO_YMAG'; format = 'D'
#     name = 'TERTIARY_VIDEO_YMAGERR'; format = 'D'
#     name = 'TERTIARY_VIDEO_JMAG'; format = 'D'
#     name = 'TERTIARY_VIDEO_JMAGERR'; format = 'D'
#     name = 'TERTIARY_VIDEO_HMAG'; format = 'D'
#     name = 'TERTIARY_VIDEO_HMAGERR'; format = 'D'
#     name = 'TERTIARY_VIDEO_KSMAG'; format = 'D'
#     name = 'TERTIARY_VIDEO_KSMAGERR'; format = 'D'
#     name = 'TERTIARY_CFHT_UMAG'; format = 'E'
#     name = 'TERTIARY_CFHT_UMAGERR'; format = 'E'
#     name = 'TERTIARY_CFHT_GMAG'; format = 'E'
#     name = 'TERTIARY_CFHT_GMAGERR'; format = 'E'
#     name = 'TERTIARY_CFHT_RMAG'; format = 'E'
#     name = 'TERTIARY_CFHT_RMAGERR'; format = 'E'
#     name = 'TERTIARY_CFHT_IMAG'; format = 'E'
#     name = 'TERTIARY_CFHT_IMAGERR'; format = 'E'
#     name = 'TERTIARY_CFHT_ZMAG'; format = 'E'
#     name = 'TERTIARY_CFHT_ZMAGERR'; format = 'E'
#     name = 'TERTIARY_HSC_GMAG'; format = 'D'
#     name = 'TERTIARY_HSC_GMAGERR'; format = 'D'
#     name = 'TERTIARY_HSC_RMAG'; format = 'D'
#     name = 'TERTIARY_HSC_RMAGERR'; format = 'D'
#     name = 'TERTIARY_HSC_IMAG'; format = 'D'
#     name = 'TERTIARY_HSC_IMAGERR'; format = 'D'
#     name = 'TERTIARY_HSC_ZMAG'; format = 'D'
#     name = 'TERTIARY_HSC_ZMAGERR'; format = 'D'
#     name = 'TERTIARY_HSC_YMAG'; format = 'D'
#     name = 'TERTIARY_HSC_YMAGERR'; format = 'D'
#     name = 'TERTIARY_ZSPEC_RA'; format = 'D'
#     name = 'TERTIARY_ZSPEC_DEC'; format = 'D'
#     name = 'TERTIARY_ZSPEC_ID'; format = 'J'; null = -2147483648
#     name = 'TERTIARY_ZSPEC'; format = 'D'
#     name = 'TERTIARY_ZSOURCE'; format = '6A'
#     name = 'TERTIARY_ZOFLAG'; format = 'E'
#     name = 'SUPPLEMENTARY_SDSS_ID'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_RA'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_DEC'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_UMAG'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_UMAGERR'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_GMAG'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_GMAGERR'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_RMAG'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_RMAGERR'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_IMAG'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_IMAGERR'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_ZMAG'; format = 'D'
#     name = 'SUPPLEMENTARY_SDSS_ZMAGERR'; format = 'D'
#     name = 'SUPPLEMENTARY_2MASS_ID'; format = '16A'
#     name = 'SUPPLEMENTARY_2MASS_RA'; format = 'D'
#     name = 'SUPPLEMENTARY_2MASS_DEC'; format = 'D'
#     name = 'SUPPLEMENTARY_2MASS_JMAG'; format = 'E'
#     name = 'SUPPLEMENTARY_2MASS_JMAGERR'; format = 'E'
#     name = 'SUPPLEMENTARY_2MASS_HMAG'; format = 'E'
#     name = 'SUPPLEMENTARY_2MASS_HMAGERR'; format = 'E'
#     name = 'SUPPLEMENTARY_2MASS_KSMAG'; format = 'E'
#     name = 'SUPPLEMENTARY_2MASS_KSMAGERR'; format = 'E'
#     name = 'SUPPLEMENTARY_DXS_ID'; format = 'D'
#     name = 'SUPPLEMENTARY_DXS_RA'; format = 'D'
#     name = 'SUPPLEMENTARY_DXS_DEC'; format = 'D'
#     name = 'SUPPLEMENTARY_DXS_JMAG'; format = 'D'
#     name = 'SUPPLEMENTARY_DXS_JMAGERR'; format = 'D'
#     name = 'SUPPLEMENTARY_DXS_KSMAG'; format = 'D'
#     name = 'SUPPLEMENTARY_DXS_KSMAGERR'; format = 'D'
#     name = 'Separation'; format = 'D'; unit = 'arcsec'
# )

# %%
ct = table.Table(catalog[1].data)
ct
# Out:
# <Table length=972>
#  cntr              object             ...      Separation
# int32              str30              ...       float64
# ------ ------------------------------ ... -------------------
# 167678 SWIRE2_J022439.09-045928.1     ...  0.6507347552128477
# 159686 SWIRE2_J022305.22-051928.3     ...  0.8214803179056188
# 330504 SWIRE2_J022144.99-045133.2     ...  0.8634988594998666
# 149299 SWIRE2_J022322.02-053404.7     ...   0.862845112517483
# 463509 SWIRE2_J021718.53-052920.6     ...  0.9186530847806537
# 332908 SWIRE2_J022051.48-045248.1     ...  0.6439255919707101
#  28028 SWIRE2_J022536.12-050313.7     ... 0.16598088885235052
# 204031 SWIRE2_J022348.63-041357.8     ...  0.6451583791387907
# 205259 SWIRE2_J022151.86-042307.1     ...  0.9785048465590106
# 160210 SWIRE2_J022248.24-052015.7     ... 0.34714967145477493
#    ...                            ... ...                 ...
# 467209 SWIRE2_J021736.54-052156.8     ...  0.8774685039283318
# 467979 SWIRE2_J021729.35-052121.9     ...  0.3532066247223136
# 337567 SWIRE2_J022020.30-044852.1     ...  0.6193248929227173
# 470152 SWIRE2_J021752.64-051535.8     ...  0.5458278942905272
# 335994 SWIRE2_J022031.96-045002.0     ... 0.24088380457710842
# 337828 SWIRE2_J021908.29-045501.5     ...  0.9198042223101529
# 468459 SWIRE2_J021655.30-052335.6     ... 0.47967682056621924
# 357649 SWIRE2_J021848.20-043116.8     ...  0.6890712560929304
# 511710 SWIRE2_J021731.10-041451.5     ...  0.9582839662930867
# 468657 SWIRE2_J021753.04-051804.5     ...  0.8478818269578475
