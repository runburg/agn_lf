# %%
# %cd ~/github/agn_lf/
import source.astro_functions as af
import source.table_functions as tf
import source.lf_xi2 as xi2
import source.lf_vmax as vmax
import source.selection_criteria as sc
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import astropy.table as table
# Out:
# /Users/runburg/github/agn_lf

# %%
catalog = fits.open("data/Anna_Nick_Tractor_photometry_samplev9_MASTER.fits", memmap=True)[1].data

# %%
flux36 = 'flux_ap2_36'
flux45 = 'flux_ap2_45'
flux58 = 'flux_ap2_58'
flux80 = 'flux_ap2_80'
fig, axs = sc.plot_wedge(catalog, flux36, flux45, flux58, flux80, selection=['lacy05', 'stern05', 'donley12'])
# Out:
# /Users/runburg/github/agn_lf/source/selection_criteria.py:49: RuntimeWarning: invalid value encountered in log10
#   lf80_45 = np.log10(flux8_0 / flux4_5)
# /Users/runburg/github/agn_lf/source/selection_criteria.py:50: RuntimeWarning: invalid value encountered in log10
#   lf58_36 = np.log10(flux5_8 / flux3_6)
# /Users/runburg/github/agn_lf/source/selection_criteria.py:53: RuntimeWarning: invalid value encountered in greater
#   agn_candidates = (lf80_45 > -0.2) & (lf58_36 > -0.1) & (lf80_45 < (0.8 * lf58_36 + 0.5))
# /Users/runburg/github/agn_lf/source/selection_criteria.py:53: RuntimeWarning: invalid value encountered in less
#   agn_candidates = (lf80_45 > -0.2) & (lf58_36 > -0.1) & (lf80_45 < (0.8 * lf58_36 + 0.5))
# /Users/runburg/github/agn_lf/source/selection_criteria.py:56: RuntimeWarning: invalid value encountered in log10
#   lf58_36 = mlf58_80 = -2.5 * np.log10(flux5_8/flux8_0)+0.634
# /Users/runburg/github/agn_lf/source/selection_criteria.py:57: RuntimeWarning: invalid value encountered in greater
#   agn_candidates = (mlf58_80 > 0.6) & (mlf36_45 > 0.2*mlf58_80+0.18) & (mlf36_45 > 2.5*mlf58_80-3.5)
# /Users/runburg/github/agn_lf/source/selection_criteria.py:59: RuntimeWarning: invalid value encountered in greater_equal
#   agn_candidates = (lf80_45 >= 0.15) & (lf58_36 >= 0.08) & (lf80_45 >= 1.21 * lf58_36 - 0.27) & (lf80_45 >= 1.21 * lf58_36 + 0.27) & (flux8_0 > flux5_8) & (flux5_8 > flux4_5) & (flux4_5 > flux3_6)
# /Users/runburg/github/agn_lf/source/selection_criteria.py:59: RuntimeWarning: invalid value encountered in greater
#   agn_candidates = (lf80_45 >= 0.15) & (lf58_36 >= 0.08) & (lf80_45 >= 1.21 * lf58_36 - 0.27) & (lf80_45 >= 1.21 * lf58_36 + 0.27) & (flux8_0 > flux5_8) & (flux5_8 > flux4_5) & (flux4_5 > flux3_6)

# %%
fig
